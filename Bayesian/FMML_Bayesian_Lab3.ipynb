# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2021-08-16 02:38:04--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   162MB/s    in 0.4s
#
# 2021-08-16 02:38:09 (162 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id  ...                                           keywords
# 38276  1508.07266v1  ...  [multilingualism, understanding, multilinguali...
# 5293    1301.0142v1  ...  [framework, supervised, adaptation, presented,...
# 28310  1706.01649v1  ...  [correspondences, presented, fundamental, cali...
# 5972    1402.0119v2  ...  [classical, principal, component, canonical, c...
# 22391  1605.05918v2  ...  [principal, component, themselves, selecting, ...
# ...             ...  ...                                                ...
# 8197   1612.00212v1  ...  [convolutional, prediction, applications, segm...
# 444     1409.6046v1  ...  [frameworks, allocating, processes, sparsifica...
# 5248    1204.1624v1  ...  [introduce, algorithm, cognitive, exponentiall...
# 27483  1703.08472v1  ...  [widespread, hospitals, repositories, increasi...
# 19054   1301.7398v1  ...  [efficiency, algorithms, secondary, structures...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 38276    [multilingualism, understanding, multilinguali...
# 5293     [framework, supervised, adaptation, presented,...
# 28310    [correspondences, presented, fundamental, cali...
# 5972     [classical, principal, component, canonical, c...
# 22391    [principal, component, themselves, selecting, ...
#                                ...
# 2848     [optimization, successful, framework, computat...
# 40922    [framework, minimization, framework, extractio...
# 22350    [partition, functions, probability, distributi...
# 8761     [computational, mechanics, structural, dimensi...
# 25935    [convolutional, demonstrated, impressive, perf...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4546 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e54b09c3-7526-49e8-9dc5-304a34531986" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e54b09c3-7526-49e8-9dc5-304a34531986")) {
#                     Plotly.newPlot(
#                         'e54b09c3-7526-49e8-9dc5-304a34531986',
#                         [{"type": "bar", "x": ["difference", "platforms", "analyzing", "different", "behaviors", "interests", "paragraphs", "understanding", "engagement", "collecting", "nonetheless", "displayed", "wikipedia", "generated", "significant", "proficiency", "languages", "primarily", "multilingual", "computational", "formidable", "complexity", "factorizes", "supervised", "multivariate", "experimental", "corrected", "illustrate", "framework", "therefore", "parametric", "introduce", "techniques", "bivariate", "factorization", "adaptation", "presented", "functions", "distributions", "regression", "technique", "polynomial", "candidates", "transformations", "parameters", "affinities", "validated", "selection", "outperforming", "correspondences", "correspondence", "estimation", "synthetic", "remaining", "especially", "conditions", "calibrated", "eliminating", "observing", "algorithm", "available", "knowledge", "fundamental", "intrinsic", "implementation", "constraints", "efficiently", "statistics", "classification", "principal", "experiments", "relationships", "ubiquitous", "construct", "classical", "computationally", "performance", "prohibitive", "randomness", "clustering", "algorithms", "canonical", "randomized", "achieving", "demonstrate", "component", "nonlinear", "correlation", "requirements", "traditional", "variables", "variational", "maximization", "selecting", "particular", "interpretation", "likelihood", "components", "procedure", "separately", "difficult", "unsupervised", "themselves", "relaxation", "expectation", "illustrated", "unlabeled", "maximized", "microarray", "dimensional", "practitioner", "probabilistic", "interpreted", "computation", "drawbacks", "optimizer", "performances", "suggestion", "correlated", "optimization", "information", "approximation", "significantly", "continuous", "dimension", "derivative", "discretized", "introduces", "evaluations", "numerical", "generalized", "sequential", "applications", "restricted", "discretization", "benchmarks", "cumulative", "sequentially", "deterministic", "probability", "independent", "informativeness", "suboptimal", "dependent", "parameter", "simulated", "scalability", "operations", "interaction", "inference", "processes", "nonparametric", "efficiency", "furthermore", "representative", "improvement", "triggering", "formulate", "competitive", "classifiers", "detecting", "convolutional", "cascading", "retraining", "recognizing", "exploiting", "relatively", "classified", "researchers", "determining", "approximating", "extremely", "generating", "feedforward", "appropriate", "generalization", "literature", "fragments", "increasing", "important", "universal", "practical", "sufficiently", "generates", "intervals", "activation", "promising", "convergence", "configuration", "cognitive", "connectome", "extracted", "groupings", "variations", "architecture", "hierarchical", "connectivity", "visualize", "resolution", "decompositions"], "y": [58, 30, 65, 736, 37, 23, 5, 142, 4, 12, 4, 5, 20, 154, 265, 4, 98, 24, 20, 302, 3, 219, 1, 231, 19, 398, 14, 70, 590, 165, 36, 322, 363, 0, 35, 72, 170, 194, 102, 118, 242, 64, 30, 49, 259, 1, 34, 169, 29, 26, 25, 195, 130, 12, 101, 142, 16, 11, 16, 864, 293, 341, 75, 45, 126, 141, 148, 59, 519, 27, 590, 84, 16, 104, 113, 82, 879, 8, 6, 137, 638, 19, 18, 84, 575, 88, 61, 76, 51, 183, 137, 45, 33, 50, 263, 52, 62, 95, 126, 31, 150, 168, 17, 22, 23, 14, 59, 6, 3, 195, 1, 146, 23, 140, 16, 4, 35, 2, 36, 342, 718, 117, 284, 119, 73, 7, 3, 75, 63, 90, 64, 87, 457, 50, 5, 99, 10, 19, 35, 158, 116, 3, 12, 85, 107, 56, 33, 67, 81, 202, 100, 18, 175, 158, 27, 161, 2, 52, 126, 113, 75, 396, 5, 12, 40, 82, 49, 21, 76, 29, 18, 46, 86, 18, 69, 103, 133, 11, 111, 338, 40, 149, 25, 51, 9, 25, 127, 119, 22, 40, 2, 118, 1, 79, 237, 97, 19, 8, 132, 7]}, {"type": "bar", "x": ["difference", "platforms", "analyzing", "different", "behaviors", "interests", "paragraphs", "understanding", "engagement", "collecting", "nonetheless", "displayed", "wikipedia",  ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4546,), (4546, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8133333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Constant</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>using</span> <span style=''>shiftable</span> <span style=''>kernels</span> <br/><br/><span style=''>It</span> <span style=''>was</span> <span style=''>recently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>in</span> <span style=''>5</span> <span style=''>that</span> <span style=''>the</span> <span style=''>non</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>bilateral</span> <span style=''>filter</span> <span style=''>14</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3026315789473684);'>implemented</span> <span style=''>using</span> <span style=''>a</span> <span style=''>constant</span> <span style=''>time</span> <span style=''>or</span> <span style=''>O(1)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>At</span> <span style=''>the</span> <span style=''>heart</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>was</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3684210526315789);'>approximating</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style=''>range</span> <span style=''>kernel</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>bilateral</span> <span style=''>filter</span> <span style=''>using</span> <span style=''>trigonometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>letter</span> <span style=''>we</span> <span style=''>explain</span> <span style=''>how</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>in</span> <span style=''>5</span> <span style=''>can</span> <span style=''>be</span> <span style=''>extended</span> <span style=''>to</span> <span style=''>few</span> <span style=''>other</span> <span style=''>linear</span> <span style=''>and</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>filters</span> <span style=''>14</span> <span style=''>17</span> <span style=''>2</span> <span style=''>While</span> <span style=''>some</span> <span style=''>of</span> <span style=''>these</span> <span style=''>filters</span> <span style=''>have</span> <span style=''>received</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.377049180327869);'>attention</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>they</span> <span style=''>are</span> <span style=''>known</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3195020746887967);'>computationally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>intensive</span> <span style=''>To</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>in</span> <span style=''>5</span> <span style=''>we</span> <span style=''>identify</span> <span style=''>a</span> <span style=''>central</span> <span style=''>property</span> <span style=''>of</span> <span style=''>trigonometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>shiftability</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Interesting</span> <span style=''>data</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrate</span> <span style=''>on</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>smooth</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>inside</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>ambient</span> <span style=''>space</span> <span style=''>Random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reduction</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>Previous</span> <span style=''>works</span> <span style=''>have</span> <span style=''>studied</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>how</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accurately</span> <span style=''>preserve</span> <span style=''>the</span> <span style=''>geometry</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>manifolds</span> <span style=''>given</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>volume</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>However</span> <span style=''>such</span> <span style=''>works</span> <span style=''>employ</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>definitions</span> <span style=''>of</span> <span style=''>volume</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>curvature</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inherently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Therefore</span> <span style=''>such</span> <span style=''>theory</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>easily</span> <span style=''>tested</span> <span style=''>against</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tightness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proven</span> <span style=''>bounds</span> <span style=''>We</span> <span style=''>instead</span> <span style=''>study</span> <span style=''>typical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distortions</span> <span style=''>arising</span> <span style=''>in</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>of</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Relative</span> <span style=''>Loss</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>On</span> <span style=''>line</span> <span style=''>Density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Estimation</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exponential</span> <span style=''>Family</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3910447761194029);'>Distributions</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>on</span> <span style=''>line</span> <span style=''>density</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameterized</span> <span style=''>density</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exponential</span> <span style=''>family</span> <span style=''>The</span> <span style=''>on</span> <span style=''>line</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>receives</span> <span style=''>one</span> <span style=''>example</span> <span style=''>at</span> <span style=''>a</span> <span style=''>time</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintains</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.31847133757961776);'>parameter</span> <span style=''>that</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>essentially</span> <span style=''>an</span> <span style=''>average</span> <span style=''>of</span> <span style=''>the</span> <span style=''>past</span> <span style=''>examples</span> <span style=''>After</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>receiving</span> <span style=''>an</span> <span style=''>example</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>incurs</span> <span style=''>a</span> <span style=''>loss</span> <span style=''>which</span> <span style=''>is</span> <span style=''>the</span> <span style=''>negative</span> <span style=''>log</span> <span style='background-color:rgba(255, 0, 0, 0.5175097276264591);'>likelihood</span> <span style=''>of</span> <span style=''>the</span> <span style=''>example</span> <span style=''>wrt</span> <span style=''>the</span> <span style=''>past</span> <span style='background-color:rgba(255, 0, 0, 0.31847133757961776);'>parameter</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>An</span> <span style=''>off</span> <span style=''>line</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>choose</span> <span style=''>the</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.31847133757961776);'>parameter</span> <span style=''>based</span> <span style=''>on</span> <span style=''>all</span> <span style=''>the</span> <span style=''>examples</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style=''>total</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style=''>on</span> <span style=''>line</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>over</span> <span style=''>the</span> <span style=''>total</span> <span style=''>loss</span> <span style=''>of</span> <span style=''>the</span> <span style=''>off</span> <span style=''>line</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Exploring</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structure</span> <span style=''>via</span> <span style=''>Axis</span> <span style=''>Aligned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <span style=''>of</span> <span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Projections</span> <br/><br/><span style=''>Two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>remain</span> <span style=''>the</span> <span style=''>dominant</span> <span style=''>approach</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>visualize</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>The</span> <span style=''>choice</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>ranges</span> <span style=''>from</span> <span style=''>highly</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>ones</span> <span style=''>which</span> <span style=''>can</span> <span style=''>capture</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>but</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpret</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quantitatively</span> <span style=''>to</span> <span style=''>axis</span> <span style=''>aligned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style=''>which</span> <span style=''>are</span> <span style=''>easy</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpret</span> <span style=''>but</span> <span style=''>are</span> <span style=''>limited</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bivariate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relationships</span> <span style=''>Linear</span> <span style=''>project</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compromise</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>as</span> <span style=''>they</span> <span style=''>allow</span> <span style=''>explicit</span> <span style=''>axes</span> <span style=''>labels</span> <span style=''>yet</span> <span style=''>provide</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>more</span> <span style=''>degrees</span> <span style=''>of</span> <span style=''>freedom</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>axis</span> <span style=''>aligned</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>projections</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nevertheless</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreting</span> <span style=''>the</span> <span style=''>axes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>directions</span> <span style=''>which</span> <span style=''>are</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>often</span> <span style=''>with</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13804230907135173)
# 	architecture (0.08497669415561133)
# 	segmentation (0.0720688418788096)
# 	challenging (0.10935819290068124)
# 	information (0.25743994263176767)
# 	experimental (0.1427034779490857)
# 	different (0.2638938687701685)
# 	detection (0.11617067049121549)
# 	recognition (0.1348153460021513)
# 	convolutional (0.14198637504481892)
#
# Some Statistics words are:
# 	distributions (0.11586275484833417)
# 	variational (0.0989557434112382)
# 	variables (0.13873694679264048)
# 	estimation (0.16907011437095973)
# 	statistical (0.15564395822973645)
# 	theoretical (0.1581302834410741)
# 	dimensional (0.18647439085032322)
# 	distribution (0.19393336648433615)
# 	inference (0.20487319741422177)
# 	regression (0.17802088513177525)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b306ddaa-6668-4eb5-8add-74d70878bea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b306ddaa-6668-4eb5-8add-74d70878bea6")) {
#                     Plotly.newPlot(
#                         'b306ddaa-6668-4eb5-8add-74d70878bea6',
#                         [{"type": "bar", "x": ["difference", "platforms", "analyzing", "different", "behaviors", "interests", "paragraphs", "understanding", "engagement", "collecting", "nonetheless", "displayed", "wikipedia", "generated", "significant", "proficiency", "languages", "primarily", "multilingual", "computational", "formidable", "complexity", "factorizes", "supervised", "multivariate", "experimental", "corrected", "illustrate", "framework", "therefore", "parametric", "introduce", "techniques", "bivariate", "factorization", "adaptation", "presented", "functions", "distributions", "regression", "technique", "polynomial", "candidates", "transformations", "parameters", "affinities", "validated", "selection", "outperforming", "correspondences", "correspondence", "estimation", "synthetic", "remaining", "especially", "conditions", "calibrated", "eliminating", "observing", "algorithm", "available", "knowledge", "fundamental", "intrinsic", "implementation", "constraints", "efficiently", "statistics", "classification", "principal", "experiments", "relationships", "ubiquitous", "construct", "classical", "computationally", "performance", "prohibitive", "randomness", "clustering", "algorithms", "canonical", "randomized", "achieving", "demonstrate", "component", "nonlinear", "correlation", "requirements", "traditional", "variables", "variational", "maximization", "selecting", "particular", "interpretation", "likelihood", "components", "procedure", "separately", "difficult", "unsupervised", "themselves", "relaxation", "expectation", "illustrated", "unlabeled", "maximized", "microarray", "dimensional", "practitioner", "probabilistic", "interpreted", "computation", "drawbacks", "optimizer", "performances", "suggestion", "correlated", "optimization", "information", "approximation", "significantly", "continuous", "dimension", "derivative", "discretized", "introduces", "evaluations", "numerical", "generalized", "sequential", "applications", "restricted", "discretization", "benchmarks", "cumulative", "sequentially", "deterministic", "probability", "independent", "informativeness", "suboptimal", "dependent", "parameter", "simulated", "scalability", "operations", "interaction", "inference", "processes", "nonparametric", "efficiency", "furthermore", "representative", "improvement", "triggering", "formulate", "competitive", "classifiers", "detecting", "convolutional", "cascading", "retraining", "recognizing", "exploiting", "relatively", "classified", "researchers", "determining", "approximating", "extremely", "generating", "feedforward", "appropriate", "generalization", "literature", "fragments", "increasing", "important", "universal", "practical", "sufficiently", "generates", "intervals", "activation", "promising", "convergence", "configuration", "cognitive", "connectome", "extracted", "groupings", "variations", "architecture", "hierarchical", "connectivity", "visualize", "resolution", "decompositions", "variability", "decompose", "precisions", "representations", "adjacency", "represents", "resolutions", "corresponds", "precision", "suggested", "representation", "autoencoder", "structures", "existence", "faithfully", "effectiveness", "underlying", "represent", "representing", "expressions", "unfortunately", "influence", "reinforcement", "sequences", "corresponding", "molecular", "discriminates", "successfully", "improving", "structure", "generative", "beginning", "individual", "evaluating", "mathematical", "recurrent", "instances", "approaches", "generally", "capacitated", "identifies", "established", "variation", "challenging", "automated", "efficient", "imitation", "experiences", "previously", "evolutionary", "encountered", "intelligent", "comprehensive", "particularly", "replicate", "structured", "optimized", "transfers", "operators", "methodologies", "innovations", "assimilate", "effective", "incorporates", "hyperparameters", "interpretable", "alternative", "automatically", "estimating", "conceptually", "interpretability", "situation", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bivariate
# 	precisions
# 	phenotypes
# 	worsening
# 	ascending
# 	jackknife
# 	reversing
# 	invertible
# 	stagewise
# 	varepsilon
# 	hermitian
# 	heckerman
# 	dobrushins
# 	exponents
# 	mcallester
# 	kontorovich
# 	bernstein
# 	resolvable
# 	microbial
# 	unnormalized
# Some words which never appear in Statistics papers:
# 	paragraphs
# 	cascading
# 	capacitated
# 	transfers
# 	syntactic
# 	antecedents
# 	coreference
# 	deblurring
# 	historically
# 	commonsense
# 	interpersonal
# 	analogical
# 	monocular
# 	transducer
# 	compilation
# 	propositional
# 	implicates
# 	connectives
# 	conscious
# 	axiomatization

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.082994203970897e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
